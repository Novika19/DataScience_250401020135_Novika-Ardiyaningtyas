# %% [markdown]
# UTS Data Science Dasar
#
# *   Nama : Novika Ardiyaningtyas
# *   NIM : 250401020135
# *   Kelas: IF401

# %%
# SEL 1: Output sederhana
print("Hello, Data Science!")

# SEL 2: Variabel & tipe data
nama = "Mahasiswa Informatika"
angkatan = 2026
print(f"Halo, {nama} angkatan {angkatan}!")

# SEL 3: List & perulangan
tools = ["Python","Colab","Jupyter","GitHub"]
for i, tool in enumerate(tools, 1):
    print(f" {i}. {tool}")

# SEL 4: Fungsi Python
def perkenalan(nama, prodi, angkatan):
    return f"{nama} | {prodi} | {angkatan}"
print(perkenalan("Novika","Informatika",2026))
# Out:
# Hello, Data Science!
# Halo, Mahasiswa Informatika angkatan 2026!
#  1. Python
#  2. Colab
#  3. Jupyter
#  4. GitHub
# Novika | Informatika | 2026

# %% [markdown]
# Kesimpulan: Praktik ini membahas dasar-dasar pemrograman Python, termasuk penggunaan fungsi "print()", variabel, tipe data, list, perulangan "for", dan pembuatan fungsi sederhana. Dengan menggunakan "print()", dapat menampilkan teks atau hasil pengolahan data ke layar. List membuat lebih mudah untuk mengelola banyak data dalam satu variabel. Dengan menggunakan perulangan "for", dapat mengakses dan menampilkan setiap elemen dalam daftar berulang kali tanpa harus menulis kode yang sama berulang kali.
